# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import stats
import datetime as dt
from pandas.plotting import table
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns

# %%
data=pd.read_csv('AMZN.csv')
data.head(2)
# Out:
#          Date     Open      High       Low     Close  Adj Close    Volume
# 0  1997-05-15  2.43750  2.500000  1.927083  1.958333   1.958333  72156000
# 1  1997-05-16  1.96875  1.979167  1.708333  1.729167   1.729167  14700000

# %% [markdown]
# Conversion to date formt datetime64[ns]

# %%
data['Date']=pd.to_datetime(data['Date'])

# %%
data.tail(2)
# Out:
#            Date         Open         High          Low        Close  \
# 5663 2019-11-14  1751.430054  1766.589966  1749.560059  1754.599976
# 5664 2019-11-15  1760.050049  1761.680054  1732.859985  1739.489990
#
#         Adj Close   Volume
# 5663  1754.599976  2264800
# 5664  1739.489990  3927600

# %% [markdown]
# checking for types so that if any data needs conversion

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5332 entries, 0 to 5331
# Data columns (total 11 columns):
# index        5332 non-null int64
# Date         5332 non-null datetime64[ns]
# Open         5332 non-null float64
# High         5332 non-null float64
# Low          5332 non-null float64
# Close        5332 non-null float64
# Adj Close    5332 non-null float64
# Volume       5332 non-null int64
# Year         5332 non-null int64
# Month        5332 non-null int64
# WeekDay      5332 non-null int64
# dtypes: datetime64[ns](1), float64(5), int64(5)
# memory usage: 458.3 KB

# %%
data.isnull().values.sum()
# Out:
# 0

# %% [markdown]
# checking for skewness and kurtosis

# %%
data.skew().sort_values()
# Out:
# Year        -0.015086
# index       -0.014680
# WeekDay     -0.006310
# Month       -0.005946
# Volume       1.886069
# Low          2.258351
# Close        2.264174
# Adj Close    2.264174
# Open         2.264764
# High         2.269315
# dtype: float64

# %%
data.kurtosis().sort_values()
# Out:
# WeekDay     -1.278893
# Month       -1.209660
# index       -1.172987
# Year        -1.164996
# Volume       4.419408
# Low          4.603281
# Close        4.636140
# Adj Close    4.636140
# Open         4.639369
# High         4.665173
# dtype: float64

# %% [markdown]
# plotting line plots seprately so that data columns can be analyzed properly

# %%
data.plot(x='Date',y='Open', subplots = True, layout = (3, 3), figsize = (15, 15), sharex = False, title = "Stock Value Trend from 1997 - 2019", rot = 90)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D4AA2B4048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D4AA259E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D4AA610EF0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D4AA6194A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D4AA5A4828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D4AA3B3BA8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A65A5160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A85A2B70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A85A2B00>]],
#       dtype=object)

# %%
data.plot(x='Date',y='High', subplots = True, layout = (3, 3), figsize = (15, 15), sharex = False, title = "Stock Value Trend from 1997 - 2019", rot = 90)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A916CEF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A9184B38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A92A6C18>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A92D7F98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A9318320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A93496A0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A937BA20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A93ADD68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A93ADDD8>]],
#       dtype=object)

# %%
data.plot(x='Date',y='Low', subplots = True, layout = (3, 3), figsize = (15, 15), sharex = False, title = "Stock Value Trend from 1997 - 2019", rot = 90)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A9649FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A3376D68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A8D05F98>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A826FD30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A860D128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A96C37B8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A824D3C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A84B2470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A84B2518>]],
#       dtype=object)

# %%
data.plot(x='Date',y='Close', subplots = True, layout = (3, 3), figsize = (15, 15), sharex = False, title = "Stock Value Trend from 1997 - 2019", rot = 90)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A83D5EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A95F7438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A89E8588>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A874C7F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A85C2A58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A857ACC0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A7F40F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A8ACD198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A8ACD208>]],
#       dtype=object)

# %%
data.plot(x='Date',y='Adj Close', subplots = True, layout = (3, 3), figsize = (15, 15), sharex = False, title = "Stock Value Trend from 1997 - 2019", rot = 90)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A83CEDA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A83CE748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A8EFF828>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A8F33A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A8F66CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A8F9DF60>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A8FDB208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A940E438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A940E4A8>]],
#       dtype=object)

# %%
data.plot(x='Date',y='Volume', subplots = True, layout = (3, 3), figsize = (15, 15), sharex = False, title = "Stock Value Trend from 1997 - 2019", rot = 90)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A94EEEF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D4A9571BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D4AA050B38>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D4AA086DA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D4AA0C0668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D4AA0F19E8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D4AA123D68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D4AA1640F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D4AA164160>]],
#       dtype=object)

# %% [markdown]
# to plot histogram of the given data

# %%
Column_List = ['Open', 'High', 'Low']
fig, ax = plt.subplots(len(Column_List), figsize = (15, 10))

for i, col_list in enumerate(Column_List):
    sns.distplot(data[col_list], hist = True, ax = ax[i])
    ax[i].set_title ("Frequency Distribution of" + " " + col_list, fontsize = 10)
    ax[i].set_xlabel (col_list, fontsize = 8)
    ax[i].set_ylabel ('Distribution Value', fontsize = 8)
    fig.tight_layout (pad = 1.1) # To provide space between plots
    ax[i].grid('on')

# %%
Column_List = ['Close', 'Adj Close', 'Volume']
fig, ax = plt.subplots(len(Column_List), figsize = (15, 10))

for i, col_list in enumerate(Column_List):
    sns.distplot(data[col_list], hist = True, ax = ax[i])
    ax[i].set_title ("Frequency Distribution of" + " " + col_list, fontsize = 10)
    ax[i].set_xlabel (col_list, fontsize = 8)
    ax[i].set_ylabel ('Distribution Value', fontsize = 8)
    fig.tight_layout (pad = 1.1) # To provide space between plots
    ax[i].grid('on')

# %%
fig.ax=plt.subplots(figsize=(20,20))
corr_matrix=data.corr()
sns.heatmap(corr_matrix, xticklabels = corr_matrix.columns.values, yticklabels = corr_matrix.columns.values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-49a583cf3b0c> in <module>
# ----> 1 fig.ax=plt.subplots(figsize=(20,20))
#       2 corr_matrix=data.corr()
#       3 sns.heatmap(corr_matrix, xticklabels = corr_matrix.columns.values, yticklabels = corr_matrix.columns.values)
#
# NameError: name 'plt' is not defined

# %%
corr_matrix
# Out:
#               index      Open      High       Low     Close  Adj Close  \
# index      1.000000  0.753223  0.752857  0.753958  0.753427   0.753427
# Open       0.753223  1.000000  0.999923  0.999873  0.999802   0.999802
# High       0.752857  0.999923  1.000000  0.999838  0.999895   0.999895
# Low        0.753958  0.999873  0.999838  1.000000  0.999911   0.999911
# Close      0.753427  0.999802  0.999895  0.999911  1.000000   1.000000
# Adj Close  0.753427  0.999802  0.999895  0.999911  1.000000   1.000000
# Volume    -0.444090 -0.288016 -0.285932 -0.290841 -0.288452  -0.288452
# Year       0.998920  0.752675  0.752317  0.753426  0.752905   0.752905
# Month     -0.009623 -0.015643 -0.015811 -0.015996 -0.016203  -0.016203
# WeekDay    0.000749 -0.000217 -0.000489 -0.000121 -0.000527  -0.000527
#
#              Volume      Year     Month   WeekDay
# index     -0.444090  0.998920 -0.009623  0.000749
# Open      -0.288016  0.752675 -0.015643 -0.000217
# High      -0.285932  0.752317 -0.015811 -0.000489
# Low       -0.290841  0.753426 -0.015996 -0.000121
# Close     -0.288452  0.752905 -0.016203 -0.000527
# Adj Close -0.288452  0.752905 -0.016203 -0.000527
# Volume     1.000000 -0.442324 -0.026328  0.010588
# Year      -0.442324  1.000000 -0.055908  0.001046
# Month     -0.026328 -0.055908  1.000000 -0.012021
# WeekDay    0.010588  0.001046 -0.012021  1.000000

# %% [markdown]
# outlier detection using whisker plots

# %%
Column_List = ['Open', 'High', 'Low']
fig, ax = plt.subplots (len(Column_List), figsize = (10, 20))

for i, col_list in enumerate(Column_List):
    sns.boxplot(data[col_list], ax = ax[i], palette = "winter", orient = 'h')
    ax[i].set_title("Whisker Plot for Outlier Detection on" + " " + col_list, fontsize = 10)
    ax[i].set_ylabel(col_list, fontsize = 8)
    fig.tight_layout(pad = 1.1)

# %%
Column_List = ['Close', 'Adj Close', 'Volume']
fig, ax = plt.subplots (len(Column_List), figsize = (10, 20))

for i, col_list in enumerate(Column_List):
    sns.boxplot(data[col_list], ax = ax[i], palette = "winter", orient = 'h')
    ax[i].set_title("Whisker Plot for Outlier Detection on" + " " + col_list, fontsize = 10)
    ax[i].set_ylabel(col_list, fontsize = 8)
    fig.tight_layout(pad = 1.1)

# %% [markdown]
# the dots above the given line shows the presence of outliers and it is clearly visible that there are outliers

# %% [markdown]
# The method used here to remove outliers is called IQR Technique

# %%
Desp_Statistics=data.describe()
Desp_Statistics=Desp_Statistics.T

# %%
Desp_Statistics['IQR']=Desp_Statistics['75%']-Desp_Statistics['25%']

# %%
data = data[(np.abs(stats.zscore(data[['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']])) < 3).all(axis = 1)]

# %%
data = data.reset_index()

# %%
data.head(2)
# Out:
#    index       Date      Open      High       Low     Close  Adj Close  \
# 0      1 1997-05-16  1.968750  1.979167  1.708333  1.729167   1.729167
# 1      2 1997-05-19  1.760417  1.770833  1.625000  1.708333   1.708333
#
#      Volume
# 0  14700000
# 1   6106800

# %% [markdown]
# we can remove index column if we need

# %% [markdown]
# Now we are looking for pattern in the columns

# %%
data['Year'] = data['Date'].dt.year
data['Month'] = data['Date'].dt.month
data['WeekDay'] = data['Date'].dt.weekday

# %%
Column_List = ['Open', 'High', 'Low']
fig, ax = plt.subplots(len(Column_List), figsize = (10, 20))
for i, col_list in enumerate(Column_List):
    data.groupby('Year')[col_list].plot(ax = ax[i], legend = True)
    ax[i].set_title("Stock Price Movement Grouped by Year on" + " " + col_list, fontsize = 10)
    ax[i].set_ylabel(col_list + " " + "Price", fontsize = 8)
    fig.tight_layout(pad = 1.1)
    ax[i].yaxis.grid(True)

# %%
Column_List = ['Close', 'Adj Close', 'Volume']
fig, ax = plt.subplots(len(Column_List), figsize = (10, 20))
for i, col_list in enumerate(Column_List):
    data.groupby('Year')[col_list].plot(ax = ax[i], legend = True)
    ax[i].set_title("Stock Price Movement Grouped by Year on" + " " + col_list, fontsize = 10)
    ax[i].set_ylabel(col_list + " " + "Price", fontsize = 8)
    fig.tight_layout(pad = 1.1)
    ax[i].yaxis.grid(True)

# %% [markdown]
# Now we are checking for trades based on year, months and day

# %%
check = data.groupby('Year')['Volume'].sum()
plt.figure(figsize = (30, 4))
ax1 = plt.subplot(121)
check.plot(y = "Volume", legend = False, fontsize = 12, sharex = False, title = "Total Volume of Stocks Traded Year-wise from 1997 - 2019", rot = 90, color = "green")
ax1.ticklabel_format(useOffset = False, style = 'plain')
ax1.set_ylabel("Total Stock Volumes")
ax1.yaxis.grid(True)

# %%
check = data.groupby('Month')['Volume'].sum()
plt.figure(figsize = (30, 4))
ax1 = plt.subplot(121)
check.plot(y = "Volume", legend = False, fontsize = 12, sharex = False, title = "Total Volume of Stocks Traded Month-wise from 1997 - 2019", rot = 90, color = "blue")
ax1.ticklabel_format(useOffset = False, style = 'plain')
ax1.set_ylabel("Total Stock Volumes")
ax1.yaxis.grid(True)

# %%
check = data.groupby('WeekDay')['Volume'].sum()
plt.figure(figsize = (30, 4))
ax1 = plt.subplot(121)
check.plot(y = "Volume", legend = False, fontsize = 12, sharex = False, title = "Total Volume of Stocks Traded WeekDay-wise from 1997 - 2019", rot = 90, color = "red")
ax1.ticklabel_format(useOffset = False, style = 'plain')
ax1.set_ylabel("Total Stock Volumes")
ax1.yaxis.grid(True)

# %% [markdown]
# pie plot to analyze year,month and weekdays

# %%
Column_List = ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']

# %%
for i, col_list in enumerate(Column_List):
    var = data.groupby('Year')[col_list].sum()

# %%
var=pd.DataFrame(var)

# %%
# Plot to understand the trend
plt.figure(figsize = (16, 7))
ax1 = plt.subplot(121)
var.plot(kind = "pie", y = "Volume", legend = False, fontsize = 12, sharex = False, title = "Time Series Influence on Total Volume Trade by Year", ax = ax1)

# %%
# Plot the table to identify numbers
ax2 = plt.subplot(122)
plt.axis('off') # Since we are plotting the table
tbl = table(ax2, var, loc = 'center')
tbl.auto_set_font_size(30)
tbl.set_fontsize(15)
plt.show()

# %%
for i, col_list in enumerate(Column_List):
    var = data.groupby('Month')[col_list].sum()
    
# Convert the variable into a pandas dataframe
var = pd.DataFrame(var)

# Plot to understand the trend
plt.figure(figsize = (16, 7))
ax1 = plt.subplot(121)
var.plot(kind = "pie", y = "Volume", legend = False, fontsize = 12, sharex = False, title = "Time Series Influence on Total Volume Trade by Month", ax = ax1)

# %%
ax2 = plt.subplot(122)
plt.axis('off') # Since we are plotting the table
tbl = table(ax2, var, loc = 'center')
tbl.auto_set_font_size(False)
tbl.set_fontsize(12)
plt.show()

# %%
for i, col_list in enumerate(Column_List):
    var = data.groupby('WeekDay')[col_list].sum()
    
# Convert the variable into a pandas dataframe
var = pd.DataFrame(var)

# Plot to understand the trend
plt.figure(figsize = (16, 7))
ax1 = plt.subplot(121)
var.plot(kind = "pie", y = "Volume", legend = False, fontsize = 12, sharex = False, title = "Time Series Influence on Total Volume Trade by WeekDay", ax = ax1)

# %%
# Plot the table to identify numbers
ax2 = plt.subplot(122)
plt.axis('off') # Since we are plotting the table
tbl = table(ax2, var, loc = 'center')
tbl.auto_set_font_size(False)
tbl.set_fontsize(12)
plt.show()

# %%
from fbprophet import Prophet

# %%
data=data.drop(columns=['Open','High','Low','Adj Close','Volume'])

# %%
data=data.rename(columns={'Date':'ds'})
data=data.rename(columns={'Close':'y'})
data
# Out:
#               ds            y
# 0     1997-05-15     1.958333
# 1     1997-05-16     1.729167
# 2     1997-05-19     1.708333
# 3     1997-05-20     1.635417
# 4     1997-05-21     1.427083
# 5     1997-05-22     1.395833
# 6     1997-05-23     1.500000
# 7     1997-05-27     1.583333
# 8     1997-05-28     1.531250
# 9     1997-05-29     1.505208
# 10    1997-05-30     1.500000
# 11    1997-06-02     1.510417
# 12    1997-06-03     1.479167
# 13    1997-06-04     1.416667
# 14    1997-06-05     1.541667
# 15    1997-06-06     1.656250
# 16    1997-06-09     1.687500
# 17    1997-06-10     1.583333
# 18    1997-06-11     1.541667
# 19    1997-06-12     1.604167
# 20    1997-06-13     1.583333
# 21    1997-06-16     1.572917
# 22    1997-06-17     1.505208
# 23    1997-06-18     1.510417
# 24    1997-06-19     1.510417
# 25    1997-06-20     1.526042
# 26    1997-06-23     1.500000
# 27    1997-06-24     1.510417
# 28    1997-06-25     1.510417
# 29    1997-06-26     1.510417
# ...          ...          ...
# 5635  2019-10-07  1732.660034
# 5636  2019-10-08  1705.510010
# 5637  2019-10-09  1721.989990
# 5638  2019-10-10  1720.260010
# 5639  2019-10-11  1731.920044
# 5640  2019-10-14  1736.430054
# 5641  2019-10-15  1767.380005
# 5642  2019-10-16  1777.430054
# 5643  2019-10-17  1787.479980
# 5644  2019-10-18  1757.510010
# 5645  2019-10-21  1785.660034
# 5646  2019-10-22  1765.729980
# 5647  2019-10-23  1762.170044
# 5648  2019-10-24  1780.780029
# 5649  2019-10-25  1761.329956
# 5650  2019-10-28  1777.079956
# 5651  2019-10-29  1762.709961
# 5652  2019-10-30  1779.989990
# 5653  2019-10-31  1776.660034
# 5654  2019-11-01  1791.439941
# 5655  2019-11-04  1804.660034
# 5656  2019-11-05  1801.709961
# 5657  2019-11-06  1795.770020
# 5658  2019-11-07  1788.199951
# 5659  2019-11-08  1785.880005
# 5660  2019-11-11  1771.650024
# 5661  2019-11-12  1778.000000
# 5662  2019-11-13  1753.109985
# 5663  2019-11-14  1754.599976
# 5664  2019-11-15  1739.489990
#
# [5665 rows x 2 columns]

# %%
m=Prophet()
m.fit(data)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
predper = 60

# %%
future = m.make_future_dataframe(periods=predper)
future.tail()
# Out:
#              ds
# 5720 2020-01-10
# 5721 2020-01-11
# 5722 2020-01-12
# 5723 2020-01-13
# 5724 2020-01-14

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds         yhat   yhat_lower   yhat_upper
# 5720 2020-01-10  2032.827011  1946.672345  2120.292699
# 5721 2020-01-11  2044.070670  1953.370168  2132.320665
# 5722 2020-01-12  2045.741803  1959.080320  2135.949094
# 5723 2020-01-13  2038.376384  1953.856162  2120.206659
# 5724 2020-01-14  2040.321200  1949.178832  2129.976337

# %%
fig1 = m.plot(forecast)

# %%
fig2 = m.plot_components(forecast)

# %%
from fbprophet.diagnostics import cross_validation

# %%
df_cv = cross_validation(m, initial='800 days', period='200 days', horizon = '365 days')
df_cv.head()
# Out:
# INFO:fbprophet:Making 36 forecasts with cutoffs between 1999-09-16 00:00:00 and 2018-11-15 00:00:00
#           ds       yhat  yhat_lower  yhat_upper        y     cutoff
# 0 1999-09-17  54.188239   47.018070   61.545021  63.8125 1999-09-16
# 1 1999-09-20  53.448372   46.176050   60.549435  62.7500 1999-09-16
# 2 1999-09-21  53.129289   45.436718   60.373770  62.2500 1999-09-16
# 3 1999-09-22  53.148026   45.754683   60.683548  66.0000 1999-09-16
# 4 1999-09-23  52.752603   45.605454   60.290887  62.2500 1999-09-16

# %%
from fbprophet.diagnostics import performance_metrics
df_p = performance_metrics(df_cv)
df_p.head()
# Out:
#   horizon          mse       rmse        mae      mape     mdape  coverage
# 0 37 days  7086.668703  84.182354  42.107142  0.224504  0.182107  0.388950
# 1 38 days  7218.327412  84.960740  42.359462  0.225634  0.181197  0.389046
# 2 39 days  7367.242985  85.832645  42.663394  0.225440  0.179955  0.388996
# 3 40 days  7486.241924  86.523072  42.933686  0.226065  0.180971  0.389215
# 4 41 days  7422.708554  86.155142  43.040486  0.229049  0.181537  0.384530

# %%
from fbprophet.plot import plot_cross_validation_metric
fig = plot_cross_validation_metric(df_cv, metric='rmse')

# %%
_
